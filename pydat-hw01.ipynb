# %% [markdown]
# # Основы анализа данных в Python
#
# *Алла Тамбовцева*
#
# ## Домашнее задание № 1
#
# ### Формат сдачи задания
#
# Для сдачи задания необходимо добавить в текущий ipynb-файл ячейки с кодом и текстом после каждого задания, сохранить изменения и загрузить итоговый файл через запрос Dropbox по ссылке, предложенной преподавателем.
#
# **Важно:** помимо кода и выдач с результатами в задачах требуется краткий ответ или интерпретация. Так как мы тренируемся решать задания и к независимому экзамену в том числе, обращайте внимание на формулировку вопросов и требуемый формат ответов. На независимом экзамене не проверяется ваш код, ожидаются ответы в корректном формате (с заданной точностью округления, в виде отдельных слов, и так далее).
#
# Всего за задание можно получить **20 баллов**.

# %% [markdown]
# В файле `owls.csv` сохранены данные, собранные для исследования паттернов поведения птенцов обыкновенной сипухи в зависимости от того, кто занимается кормлением, мама-сова или папа-сова.
#
# Переменные в файле:
#
# * `Nest`: расположение гнезда (название местности);
#
# * `FoodTreatment`: голодный птенец (`Deprived`) или сытый (`Satiated`);
#
# * `SexParent`: пол родителя птенца (`Female` or `Male`), который приносит добычу;
#
# * `ArrivalTime`: время, когда родитель прилетает в гнездо с добычей (специфический отсчет,
# фиксировалось время с 21:30 до 05:30, после полуночи время не сбрасывалось, поэтому возможны значения более 24).
#
# * `SiblingNegotiation`: частота общения птенцов друг с другом;
#
# * `BroodSize`: количество птенцов в гнезде;
#
# * `logBroodSize`: количество птенцов в гнезде (натуральный логарифм);
#
# * `NegPerChick`: усредненное число «просьб» о еде для каждого птенца.
#
# Загрузите данные из файла `owls.csv` и выполните задания ниже.

# %% [markdown]
# ### Задача 1 (1 балл)
#
# Итак, начнём с насущного вопроса: каких птенцов в нашей выборке больше, голодных или сытых? Выведите таблицу частот для столбца `FoodTreatment` и запишите моду.

# %%
# YOUR CODE HERE

# %% [markdown]
# **ОТВЕТ:**

# %% [markdown]
# ### Задача 2 (1 балл)
#
# Выясним, в каких населённых пунктах производилось наблюдение за совами. Выведите перечень уникальных значений столбца `Nest`, посчитайте их число и запишите ответ. Дополнительно: проявите исследовательское любопытство и запишите название страны, где есть такие населённые пункты.

# %%
# YOUR CODE HERE

# %% [markdown]
# **ОТВЕТ:**

# %% [markdown]
# **Дополнительно:**

# %% [markdown]
# ### Задача 3 (3 балла)
#
# Поймём, есть ли населённые пункты в нашей выборке, где число голодных и сытых птенцов сильно отличается друг от друга. Для этого сформируйте таблицу сопряжённости, где по строкам указаны населённые пункты (`Nest`), а по столбцам – тип птенца (`FoodTreatment`), и добавьте туда столбец с разницей между числом голодных и сытых птенцов. Укажите название населённого пункта, где эта разница наибольшая по модулю.

# %%
# YOUR CODE HERE

# %% [markdown]
# **ОТВЕТ:**

# %% [markdown]
# ### Задача 4 (2 балла)
#
# Голодных птенцов необходимо накормить. Мама-сова или папа-сова прилетают с добычей в определённое время. Показатель времени в этом наборе данных довольно специфичный, поэтому попробуем разобраться с его значениями. Выведите основные описательные статистики для столбца `ArrivalTime`. Проинтерпретируйте полученные результаты.

# %%
# YOUR CODE HERE

# %% [markdown]
# **ОТВЕТ:**

# %% [markdown]
# ### Задача 5 (2 балла)
#
# Согласно теории исследователей, птенцы ведут себя по-разному в зависимости от того, кто кормит птенца, мама или папа. Давайте попробуем выполнить разведывательный анализ и посмотреть на особенности. Сгруппируйте наблюдения по полу кормящего родителя (столбец `SexParent`) и выведите средние значения числовых показателей по каждой группе. В каком случае птенцы общаются между собой чаще (`SiblingNegotiation`), когда их кормит мама-сова или папа-сова? Укажите ответ на вопрос в виде `Female` или `Male`.

# %%
# YOUR CODE HERE

# %% [markdown]
# **ОТВЕТ:**

# %% [markdown]
# ### Задача 6 (2 балла)
#
# Сгруппируйте наблюдения по полу кормящего родителя (столбец `SexParent`) и выведите средние и медианные значения числовых показателей по каждой группе. Можно ли считать распределение частоты общения птенцов между собой (`SiblingNegotiation`) симметричным? Обоснуйте свой ответ и, если распределение является скошенным, укажите, с какой стороны находятся менее типичные значения, справа или слева.

# %%
# YOUR CODE HERE

# %% [markdown]
# **ОТВЕТ:**

# %% [markdown]
# ### Задача 7 (2 балла)
#
# Сгруппируйте наблюдения по полу кормящего родителя (столбец `SexParent`) и выведите средние значения и стандартные отклонения числовых показателей по каждой группе. В каком случае, при кормлении мамой или папой, значения числа просьб о еде (`NegPerChick`) являются более разнообразными? Укажите ответ в виде `Female` или `Male` и обоснуйте свой ответ.

# %%
# YOUR CODE HERE

# %% [markdown]
# **ОТВЕТ:**

# %% [markdown]
# ### Задача 8 (2 балла)
#
# Пора понять, в каком населённом пункте живут самые требовательные совята. Вычислите максимальное значение по столбцу `NegPerChick` и сохраните его в переменную `high`. Отфильтруйте строки, соответствующие максимальному значению `NegPerChick`. Укажите название (или названия) населённых пунктов с самыми требовательными совятами.

# %%
# YOUR CODE HERE

# %% [markdown]
# **ОТВЕТ:**

# %% [markdown]
# ### Задача 9 (2 балла)
#
# Вычислите среднее число птенцов в гнезде (столбец `BroodSize`) для семейств сов, которые живут в Yvonnand или Gletterens (столбец `Nest`). Укажите ответ, округлённный до целых в меньшую сторону.

# %%
# YOUR CODE HERE

# %% [markdown]
# **ОТВЕТ:**

# %% [markdown]
# ### Задача 10 (3 балла)
#
# Добавьте в датафрейм новый столбец `TimeCode` с закодированными значениями `ArrivalTime`: если значение времени больше 24, ставится 1, если не более 24, ставится 0. Определите среднее значение показателя `TimeCode` и округлите его до сотых.

# %%
# YOUR CODE HERE

# %% [markdown]
# **ОТВЕТ:**
